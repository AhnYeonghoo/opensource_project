# %%
import pandas as pd
import os

# 1학기 컴퓨터공학과 전공(0번 시트)
class FirstComputerMajor:
    data=pd.read_excel("2021_1_Lecture.xlsx",sheet_name=0)
    db=pd.DataFrame(data, columns=['학년','이수구분','과목코드','과목명','학점','성적부여'])
    subject_code=pd['과목코드'].tolist()

# 1학기 소프트웨어학과 전공(1번 시트)
class FirstSoftwareMajor:
    data=pd.read_excel("2021_1_Lecture.xlsx",sheet_name=1)
    db=pd.DataFrame(data, columns=['학년','이수구분','과목코드','과목명','학점','성적부여'])

# 1학기 OCU(2번 시트)
class FirstOCU:
     data=pd.read_excel("2021_1_Lecture.xlsx",sheet_name=2)
     db=pd.DataFrame(data, columns=['학년','이수구분','과목코드','과목명','학점','성적부여'])

# 1학기 개신기초교양(3번 시트)
class FirstGaesinBasicLiberal:
    data=pd.read_excel("2021_1_Lecture.xlsx",sheet_name=3)
    db=pd.DataFrame(data, columns=['학년','이수구분','과목코드','과목명','학점','성적부여'])

# 1학기 일반교양: 인간과문화(4번 시트)
class FirstLiberalHumanAndCulture:
    data=pd.read_excel("2021_1_Lecture.xlsx",sheet_name=4)
    db=pd.DataFrame(data, columns=['학년','이수구분','과목코드','과목명','학점','성적부여'])

# %%
data=pd.read_excel("2021_1_Lecture.xlsx",sheet_name=0,dtype=str)

# %%
db=pd.DataFrame(data, columns=['학년','이수구분','과목코드','과목명','학점','성적부여'])

# %%
db
# Out:
#      학년  이수구분     과목코드         과목명   학점      성적부여
# 0   NaN   NaN      NaN         NaN  NaN       NaN
# 1   1학년  전공필수  5110001      창의공학설계    2     Grade
# 2   1학년  전공선택  5110051     컴퓨터공학개론    3     Grade
# 3   1학년  전공필수  5110122      미래설계탐색    1  PassFail
# 4   2학년  전공필수  5110005        이산수학    3     Grade
# 5   2학년  전공선택  5110007  C/C++프로그래밍    3     Grade
# 6   2학년  전공선택  5110047       데이터통신    3     Grade
# 7   2학년  전공선택  5110054        자료구조    3     Grade
# 8   2학년  전공필수  5110121      미래설계구현    1  PassFail
# 9   2학년  전공선택  5110124     전자회로및설계    3     Grade
# 10  2학년  전공선택  5110125  오픈소스기초프로젝트    2     Grade
# 11  2학년  전공선택  5110146  고급컴퓨터프로그래밍    3     Grade
# 12  2학년  전공선택  5110147        논리회로    3     Grade
# 13  3학년  전공필수  5110011       컴퓨터구조    3     Grade
# 14  3학년  전공필수  5110016        운영체제    3     Grade
# 15  3학년  전공필수  5110018    프로그래밍언어론    3     Grade
# 16  3학년  전공선택  5110068    인터넷프로그래밍    3     Grade
# 17  3학년  전공선택  5110099        알고리즘    3     Grade
# ...
