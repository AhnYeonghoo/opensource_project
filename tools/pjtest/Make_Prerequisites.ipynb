# %%
import os
import pandas as pd
file_name='컴퓨터공학과_선수과목.xlsx'

# %%
df=pd.read_excel(file_name,dtype=str)

# %%
df.filter(['과목명','선수과목명','적용구분','시작년도','종료년도']).drop_duplicates(['과목명','선수과목명','종료년도'])
# Out:
#                       과목명                    선수과목명    적용구분  시작년도  종료년도
# 0                     NaN                      NaN     NaN   NaN   NaN
# 1    C/C++프로그래밍 (5110007)     기초컴퓨터프로그래밍 (0914002)  특정구간학번  2015  2019
# 9    C/C++프로그래밍 (5110007)     기초컴퓨터프로그래밍 (0914002)  특정학번부터  2019   NaN
# 17   C/C++프로그래밍 (5110007)     기초컴퓨터프로그래밍 (0622013)  특정학번부터  2015   NaN
# 21   C/C++프로그래밍 (5110007)     기초컴퓨터프로그래밍 (0622013)  특정구간학번  2015  2018
# 37        컴퓨터구조 (5110011)          디지털공학 (5110003)  특정학번부터  2015   NaN
# 45        컴퓨터구조 (5110011)        논리회로및설계 (5110128)  특정구간학번  2015  2019
# 57        선형대수학 (5110013)           수학II (0621003)  특정구간학번  2015  2018
# 73        선형대수학 (5110013)           수학II (0621003)  특정학번부터  2015   NaN
# 77        선형대수학 (5110013)           수학II (0941003)  특정학번부터  2019   NaN
# 85        선형대수학 (5110013)           수학II (0941003)  특정구간학번  2019  2019
# 93         컴파일러 (5110024)  정형문법 및 자동화 이론 (5110012)  특정학번부터  2015   NaN
# ...

# %%
result=df.filter(['과목명','선수과목명','적용구분','시작년도','종료년도']).drop_duplicates(['과목명','선수과목명','종료년도'])

# %%
result=result.values

# %%
result
# Out:
# array([[nan, nan, nan, nan, nan],
#        ['C/C++프로그래밍 (5110007)', '기초컴퓨터프로그래밍 (0914002)', '특정구간학번', '2015',
#         '2019'],
#        ['C/C++프로그래밍 (5110007)', '기초컴퓨터프로그래밍 (0914002)', '특정학번부터', '2019',
#         nan],
#        ['C/C++프로그래밍 (5110007)', '기초컴퓨터프로그래밍 (0622013)', '특정학번부터', '2015',
#         nan],
#        ['C/C++프로그래밍 (5110007)', '기초컴퓨터프로그래밍 (0622013)', '특정구간학번', '2015',
#         '2018'],
#        ['컴퓨터구조 (5110011)', '디지털공학 (5110003)', '특정학번부터', '2015', nan],
#        ['컴퓨터구조 (5110011)', '논리회로및설계 (5110128)', '특정구간학번', '2015', '2019'],
#        ['선형대수학 (5110013)', '수학II (0621003)', '특정구간학번', '2015', '2018'],
#        ['선형대수학 (5110013)', '수학II (0621003)', '특정학번부터', '2015', nan],
#        ['선형대수학 (5110013)', '수학II (0941003)', '특정학번부터', '2019', nan],
#        ['선형대수학 (5110013)', '수학II (0941003)', '특정구간학번', '2019', '2019'],
#        ['컴파일러 (5110024)', '정형문법 및 자동화 이론 (5110012)', '특정학번부터', '2015',
#         nan],
# ...

# %%
class Prerequisits:
    def __init__(self, key, value):
        self.key=key
        self.value=value 

upper_subject=['5110007',   #c++
                '5110011',  #컴퓨터구조 
                '5110013',  #선형대수학
                '5110025',  #데이터베이스시스템
                '5110089',  #분산컴퓨팅시스템
                '5110099',  #알고리즘
                '5110107']  #마이크로프로세서

lower_subject=[ '0914002',  # 기초컴퓨터프로그래밍
                '5110128',  # 논리회로및설계
                '0621003',  # 수학2
                '5110014',  # 데이터구조
                '5110012',  # 정형문법 및 자동화 이론
                '5110014',  # 데이터 구조
                '5110011']  # 컴퓨터구조
