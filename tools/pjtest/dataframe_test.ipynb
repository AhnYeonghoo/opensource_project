# %%
#class Contact:
#    def __init__(self,이수구분,영역,세부영역,교과목번호,교과목명,학점,keyword):
#        self.이수구분=이수구분
#        self.영역=영역
#        self.세부영역=세부영역
#        self.교과목번호 = 교과목번호
#        self.교과목명 = 교과목명
#        self.학점 = 학점
#        self.keyword=keyword
#
#    def
#

# %%
import os
import numpy as np
import pandas as pd
from IPython import display

pd.options.display.max_rows = 999 # 데이터 프레임 표시 최대 열수를 999로 지정
pd.set_option('display.max_columns', 999) # 데이터 프레임 표시 최대 행수를 999로 지정

# %%
# get excel data to dataframe
file_name = '2021_1_Lecture.xlsx'
df = pd.read_excel(file_name,dtype=str)

# %%
result=pd.DataFrame(df, columns=['학년','이수구분','과목코드','과목명','학점','성적부여'])

# %%
result
# Out:
#      학년  이수구분     과목코드         과목명   학점      성적부여
# 0   NaN   NaN      NaN         NaN  NaN       NaN
# 1   1학년  전공필수  5110001      창의공학설계    2     Grade
# 2   1학년  전공선택  5110051     컴퓨터공학개론    3     Grade
# 3   1학년  전공필수  5110122      미래설계탐색    1  PassFail
# 4   2학년  전공필수  5110005        이산수학    3     Grade
# 5   2학년  전공선택  5110007  C/C++프로그래밍    3     Grade
# 6   2학년  전공선택  5110047       데이터통신    3     Grade
# 7   2학년  전공선택  5110054        자료구조    3     Grade
# 8   2학년  전공필수  5110121      미래설계구현    1  PassFail
# 9   2학년  전공선택  5110124     전자회로및설계    3     Grade
# 10  2학년  전공선택  5110125  오픈소스기초프로젝트    2     Grade
# 11  2학년  전공선택  5110146  고급컴퓨터프로그래밍    3     Grade
# 12  2학년  전공선택  5110147        논리회로    3     Grade
# 13  3학년  전공필수  5110011       컴퓨터구조    3     Grade
# 14  3학년  전공필수  5110016        운영체제    3     Grade
# 15  3학년  전공필수  5110018    프로그래밍언어론    3     Grade
# 16  3학년  전공선택  5110068    인터넷프로그래밍    3     Grade
# 17  3학년  전공선택  5110099        알고리즘    3     Grade
# ...

# %%
rusult=pd.DataFrame(df, columns=['과목코드'])

# %%
rusult
# Out:
#        과목코드
# 0       NaN
# 1   5110001
# 2   5110051
# 3   5110122
# 4   5110005
# 5   5110007
# 6   5110047
# 7   5110054
# 8   5110121
# 9   5110124
# 10  5110125
# 11  5110146
# 12  5110147
# 13  5110011
# 14  5110016
# 15  5110018
# 16  5110068
# 17  5110099
# 18  5110109
# 19  5110130
# 20  5110132
# 21  5100012
# 22  5110034
# 23  5110089
# 24  5110106
# 25  5110135
# 26  5110136
# 27  5110137
# 28  5110138
# 29  5110155
# 30  5110156
# 31  5110157

# %%
rusult.isin(['5110157'])
# Out:
#      과목코드
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18  False
# 19  False
# 20  False
# 21  False
# 22  False
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31   True

# %%
# Out:
#        과목코드
# 0       NaN
# 1   5110001
# 2   5110051
# 3   5110122
# 4   5110005
# 5   5110007
# 6   5110047
# 7   5110054
# 8   5110121
# 9   5110124
# 10  5110125
# 11  5110146
# 12  5110147
# 13  5110011
# 14  5110016
# 15  5110018
# 16  5110068
# 17  5110099
# 18  5110109
# 19  5110130
# 20  5110132
# 21  5100012
# 22  5110034
# 23  5110089
# 24  5110106
# 25  5110135
# 26  5110136
# 27  5110137
# 28  5110138
# 29  5110155
# 30  5110156
# 31  5110157

# %%
rresult=result.values.tolist()

# %%
rresult
# Out:
# [[nan, nan, nan, nan, nan, nan],
#  ['1학년', '전공필수', 5110001.0, '창의공학설계', 2.0, 'Grade'],
#  ['1학년', '전공선택', 5110051.0, '컴퓨터공학개론', 3.0, 'Grade'],
#  ['1학년', '전공필수', 5110122.0, '미래설계탐색', 1.0, 'PassFail'],
#  ['2학년', '전공필수', 5110005.0, '이산수학', 3.0, 'Grade'],
#  ['2학년', '전공선택', 5110007.0, 'C/C++프로그래밍', 3.0, 'Grade'],
#  ['2학년', '전공선택', 5110047.0, '데이터통신', 3.0, 'Grade'],
#  ['2학년', '전공선택', 5110054.0, '자료구조', 3.0, 'Grade'],
#  ['2학년', '전공필수', 5110121.0, '미래설계구현', 1.0, 'PassFail'],
#  ['2학년', '전공선택', 5110124.0, '전자회로및설계', 3.0, 'Grade'],
#  ['2학년', '전공선택', 5110125.0, '오픈소스기초프로젝트', 2.0, 'Grade'],
#  ['2학년', '전공선택', 5110146.0, '고급컴퓨터프로그래밍', 3.0, 'Grade'],
#  ['2학년', '전공선택', 5110147.0, '논리회로', 3.0, 'Grade'],
#  ['3학년', '전공필수', 5110011.0, '컴퓨터구조', 3.0, 'Grade'],
#  ['3학년', '전공필수', 5110016.0, '운영체제', 3.0, 'Grade'],
#  ['3학년', '전공필수', 5110018.0, '프로그래밍언어론', 3.0, 'Grade'],
#  ['3학년', '전공선택', 5110068.0, '인터넷프로그래밍', 3.0, 'Grade'],
#  ['3학년', '전공선택', 5110099.0, '알고리즘', 3.0, 'Grade'],
# ...
